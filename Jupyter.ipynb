# %%
import matplotlib.pyplot as plt

print("boo")
# Out:
# boo

# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
print("installing plotly")
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# installing plotly

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\rb902100\Documents\growing.csv')
#py.iplot(data, filename='jupyter-basic_bar')

print(data)
# Out:
#      x   y
# 0    2   4
# 1    3   4
# 2    4   6
# 3    5   7
# 4    6   9
# 5    7  18
# 6    8  40
# 7    9  70
# 8   10  80
# 9   11  90
# 10  12  96

# %%
data.plot(kind='scatter',x='x',y='y')
plt.show()

# %%
data2 = pd.read_csv(r'C:\Users\rb902100\Documents\growing2.csv')
#py.iplot(data, filename='jupyter-basic_bar')

print(data2)
# Out:
#         x    y
# 0   15.75  124
# 1   15.50  126
# 2   15.25  123
# 3   15.00  126
# 4   14.75  123
# ..    ...  ...
# 59   1.00   79
# 60   0.75   67
# 61   0.50   55
# 62   0.25   59
# 63   0.00   52
#
# [64 rows x 2 columns]

# %%
data2.plot(kind='scatter',x='x',y='y')
plt.show()

# %%
#THIS BIT EXPLORES OTHER PLOTTING LIBRARIES
import plotly as pltly
import pyqtgraph as pyq 

print("trying other libraries")
# Out:
# hello

# %%
#Spare stuff below here

# %%
import sys
# !conda install --yes --prefix {sys.prefix} pyqtgraph
print("installing library")
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# installing library
